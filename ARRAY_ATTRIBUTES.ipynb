# %%
import numpy as np

# %%
arr1=np.array([[1,2,3,4],[4,5,6,7],[3,4,5,6]])
arr1
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7],
#        [3, 4, 5, 6]])

# %%
#this wwill give the shape of any array
np.shape(arr1)
# Out:
# (3, 4)

# %%
# this will give the size or number of elements
np.size(arr1)
# Out:
# 12
