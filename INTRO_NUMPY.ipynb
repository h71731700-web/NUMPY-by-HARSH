# %%
import numpy as np

# %%
#creation of numpy array
array1=[1,2,3,4,5,6]
arr=np.array(array1)
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#conversion of list into array
list1=["harsh",1,2,3,"vansh"]
arr2=np.array(list1)
arr2
# Out:
# array(['harsh', '1', '2', '3', 'vansh'], dtype='<U21')

# %%
# vector form of array array
d=[[1,2,3,4,5],[2,4,5,6,7],[3,4,5,6,7]]
d2=np.array(d)
d2
# Out:
# array([[1, 2, 3, 4, 5],
#        [2, 4, 5, 6, 7],
#        [3, 4, 5, 6, 7]])

# %%
np.array([[1,2,3,4,5],[3,4,5,6,7]])
# Out:
# array([[1, 2, 3, 4, 5],
#        [3, 4, 5, 6, 7]])
